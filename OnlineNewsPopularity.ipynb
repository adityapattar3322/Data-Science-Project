# %% [markdown]
# # Importing Libraries

# %%
import numpy as np 
import pandas as pd # data manipulation
import matplotlib.pyplot as plt # data visualization
# %matplotlib inline

# %% [markdown]
# # Importing Dataset

# %%
df = pd.read_csv("D:\Cognition Tech\Data Science Projects\Online News Popularity\OnlineNewsPopularity.csv")
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\adity\AppData\Local\Temp\ipykernel_7536\2247596971.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df = pd.read_csv("D:\Cognition Tech\Data Science Projects\Online News Popularity\OnlineNewsPopularity.csv")
#                                                  url  timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...        731
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...        731
# 2  http://mashable.com/2013/01/07/apple-40-billio...        731
# 3  http://mashable.com/2013/01/07/astronaut-notre...        731
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/        731
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0              12               219         0.663594               1.0
# 1               9               255         0.604743               1.0
# ...

# %%
df.head() # returns 1st 5 rows of the dataframe
# Out:
#                                                  url  timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...        731
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...        731
# 2  http://mashable.com/2013/01/07/apple-40-billio...        731
# 3  http://mashable.com/2013/01/07/astronaut-notre...        731
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/        731
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0              12               219         0.663594               1.0
# 1               9               255         0.604743               1.0
# 2               9               211         0.575130               1.0
# 3               9               531         0.503788               1.0
# 4              13              1072         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  ...  \
# 0                  0.815385          4               2         1  ...
# ...

# %%
df.shape # returns the shape of the dataframe means usually Rows and columns hence there are no duplicates in dataframe
# Out:
# (39644, 61)

# %%
df.isna() #returns the missing value if present in the columns
# Out:
#          url  timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 0      False      False           False             False            False
# 1      False      False           False             False            False
# 2      False      False           False             False            False
# 3      False      False           False             False            False
# 4      False      False           False             False            False
# ...      ...        ...             ...               ...              ...
# 39639  False      False           False             False            False
# 39640  False      False           False             False            False
# 39641  False      False           False             False            False
# 39642  False      False           False             False            False
# 39643  False      False           False             False            False
#
# ...

# %%
df.info() # summarizes the entire dataframe like like column details and its datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39644 entries, 0 to 39643
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   url                             39644 non-null  object
#  1   timedelta                       39644 non-null  int64
#  2   n_tokens_title                  39644 non-null  int64
#  3   n_tokens_content                39644 non-null  int64
#  4   n_unique_tokens                 39644 non-null  float64
#  5   n_non_stop_words                39644 non-null  float64
#  6   n_non_stop_unique_tokens        39644 non-null  float64
#  7   num_hrefs                       39644 non-null  int64
#  8   num_self_hrefs                  39644 non-null  int64
#  9   num_imgs                        39644 non-null  int64
#  10  num_videos                      39644 non-null  int64
#  11  average_token_length            39644 non-null  float64
# ...

# %%
df = df.drop_duplicates() 
df.shape
# Out:
# (39644, 61)

# %%
n = df.isna().sum() # checking all variables that contain missing values
n
# Out:
# url                             0
# timedelta                       0
# n_tokens_title                  0
# n_tokens_content                0
# n_unique_tokens                 0
#                                ..
# title_subjectivity              0
# title_sentiment_polarity        0
# abs_title_subjectivity          0
# abs_title_sentiment_polarity    0
# shares                          0
# Length: 61, dtype: int64

# %% [markdown]
# # Getting the Statistics of Original Target Attributes

# %%
# popularity = df[df.keys()[-1]]
# popularity_stats = popularity.describe()
# popularity_stats

# %%
# popularity.median()

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## 1. Statistical Details About the Dataset

# %%
df.describe() # Statistical Details About the Dataset.
# Out:
#           timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# count  39644.000000    39644.000000      39644.000000     39644.000000
# mean     354.530471       10.398749        546.514731         0.548216
# std      214.163767        2.114037        471.107508         3.520708
# min        8.000000        2.000000          0.000000         0.000000
# 25%      164.000000        9.000000        246.000000         0.470870
# 50%      339.000000       10.000000        409.000000         0.539226
# 75%      542.000000       12.000000        716.000000         0.608696
# max      731.000000       23.000000       8474.000000       701.000000
#
#        n_non_stop_words  n_non_stop_unique_tokens     num_hrefs  \
# count      39644.000000              39644.000000  39644.000000
# mean           0.996469                  0.689175     10.883690
# std            5.231231                  3.264816     11.332017
# min            0.000000                  0.000000      0.000000
# ...

# %%
df.dtypes
# Out:
# url                              object
# timedelta                         int64
# n_tokens_title                    int64
# n_tokens_content                  int64
# n_unique_tokens                 float64
#                                  ...
# title_subjectivity              float64
# title_sentiment_polarity        float64
# abs_title_subjectivity          float64
# abs_title_sentiment_polarity    float64
# shares                            int64
# Length: 61, dtype: object

# %% [markdown]
# ## 2. Visualization of Dataset

# %%
df.hist(figsize=(30,30))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 3. Dropping the Non-numeric and Unwanted columns

# %%
df =df.drop('url', axis=1)
df = df.drop(['n_unique_tokens','n_non_stop_words','kw_avg_min'],axis=1)

# %%
df.shape
# Out:
# (39644, 57)

# %% [markdown]
# ## 4.  Understanding Target Variable

# %%
df['shares'].describe()
# Out:
# count     39644.000000
# mean       3395.380184
# std       11626.950749
# min           1.000000
# 25%         946.000000
# 50%        1400.000000
# 75%        2800.000000
# max      843300.000000
# Name: shares, dtype: float64

# %%
df['shares'].median()
# Out:
# np.float64(1400.0)

# %% [markdown]
# - Since, to set the threshold for deciding whether an article is popular. We should chooose the median number of of shares in the dataset.
# - All the Articles with 1400 or more shares are marked to be POPULAR and less than 1400 shares are considered as UNPOPULAR
# - for which we need to create new target variable

# %%
df['popularity'] = df['shares'].apply(lambda x: 0 if x<1400 else 1)

# %%
df.hist(column='popularity')
# Out:
# array([[<Axes: title={'center': 'popularity'}>]], dtype=object)

# %% [markdown]
# ## Number of Words in Content VS Number of Shares

# %%
# %matplotlib inline
plt.xlabel('n_tokens_title')
plt.ylabel('shares')
plt.scatter(df.n_tokens_title , df.shares, color = 'black' , marker = '.')

# %% [markdown]
# ## Number of Words in Title VS Number of Shares

# %%
# %matplotlib inline
plt.xlabel('n_tokens_content')
plt.ylabel('shares')
plt.scatter(df.n_tokens_content , df.shares, color = 'black' , marker = '.')

# %%
a = df['shares'].mean()
b = df['shares'].median()
a,b
# Out:
# (np.float64(3395.3801836343455), np.float64(1400.0))

# %%
print(f'Mean Article Shares = {a}')
print(f'Median Article Shares = {b}')
# Out:
# Mean Article Shares = 3395.3801836343455
# Median Article Shares = 1400.0

# %%
wday = df.columns.values[27:34]
wday
# Out:
# array(['weekday_is_monday', 'weekday_is_tuesday', 'weekday_is_wednesday',
#        'weekday_is_thursday', 'weekday_is_friday', 'weekday_is_saturday',
#        'weekday_is_sunday'], dtype=object)

# %%
unpop = df[df['shares']<b]
pop = df[df['shares']>=b]

pop_day = pop[wday].sum().values
unpop_day = unpop[wday].sum().values

fig = plt.figure(figsize = (13,5))
plt.title("Count of Popular and Unpopular News over different day of week (Median)",fontsize = 16)

plt.bar(np.arange(len(wday)), pop_day, width=0.3, align = 'center',color='blue', label ='Popular')
plt.bar(np.arange(len(wday))-0.3, unpop_day, width=0.3, align = 'center',color='red', label ='Unpopular') 

plt.xticks(np.arange(len(wday)),wday)
plt.ylabel('COUNT',fontsize = 15)
plt.xlabel('Day of Week', fontsize=17)

plt.legend(loc = 'upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Best Popular Articles are usually posted on Monday and Wednesday and (little Bit of Tuesday)
# - Generally weekends (Sunday and Saturday) are the worst days to publish an article

# %%
dc = df.columns[10:16]
dc
# Out:
# Index(['data_channel_is_lifestyle', ' data_channel_is_entertainment',
#        'data_channel_is_bus', 'data_channel_is_socmed', 'data_channel_is_tech',
#        'data_channel_is_world'],
#       dtype='object')

# %%
unpop1 = df[df['shares']<b]
pop1 = df[df['shares']>=b]

pop_day1 = pop[dc].sum().values
unpop_day1 = unpop[dc].sum().values

fig = plt.figure(figsize = (13,5))
plt.title("Count of Popular and Unpopular News over different Data Channel (Median)",fontsize = 16)

plt.bar(np.arange(len(dc)), pop_day1, width=0.3, align = 'center',color='Green', label ='Popular')
plt.bar(np.arange(len(dc))-0.3, unpop_day1, width=0.3, align = 'center',color='lightgreen', label ='Unpopular') 

plt.xticks(np.arange(len(dc)),dc)
plt.ylabel('COUNT',fontsize = 15)
plt.xlabel('Day of Week', fontsize=17)

plt.legend(loc = 'upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# - The Tech_channel & Business_channel are great for best Popularity
# - Coming in the 3rd Position will be the World_channel and Entertainment_channel

# %%
X = df.drop(['popularity'],axis=1)
y = df['popularity']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 2)

# %% [markdown]
# - As our target variable is 'Popularity' as created initially...so for the train and test the target variable is been used

# %%
X_train.shape
# Out:
# (31715, 57)

# %%
X_test.shape
# Out:
# (7929, 57)

# %%
y_train.shape
# Out:
# (31715,)

# %%
y_test.shape
# Out:
# (7929,)

# %%
from sklearn.linear_model import LogisticRegression
model =LogisticRegression()

# %% [markdown]
# - The Reason behind using the Logistic Regression for the dataset as the feature is in Categorial Form (Popular and Unpopular)

# %%
model.fit(X_train,y_train)
# Out:
# C:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
model.predict_proba(X_test)
# Out:
# array([[0.96283554, 0.03716446],
#        [0.0096217 , 0.9903783 ],
#        [0.54261801, 0.45738199],
#        ...,
#        [0.61816669, 0.38183331],
#        [0.55245185, 0.44754815],
#        [0.98481138, 0.01518862]])

# %%
model.score(X_test,y_test)
# Out:
# 0.9142388699709926

# %% [markdown]
# # Our Score is about 91.42%
